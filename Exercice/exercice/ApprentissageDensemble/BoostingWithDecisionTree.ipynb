# %% [markdown]
# **Make Dataset and display it**

# %%
from sklearn.datasets import make_classification
X_bruit, y_bruit = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=10,
    n_redundant=5,
    n_repeated=0,
    n_classes=2,
    flip_y=0.1,  # bruit dans les labels
    class_sep=0.5,  # classes proches
    random_state=42
)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import matplotlib.pyplot as plt
# Affichage
plt.figure(figsize=(8, 6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolor='k')
plt.xlabel("Composante principale 1")
plt.ylabel("Composante principale 2")
plt.grid(True)
plt.show()

# Affichage
plt.figure(figsize=(8, 6))
plt.scatter(X_train[:, 2], X_train[:, 3], c=y_train, cmap=plt.cm.RdYlBu, edgecolor='k')
plt.xlabel("Composante principale 2")
plt.ylabel("Composante principale 3")
plt.grid(True)
plt.show()

# %% [markdown]
# **Train an evaluate with DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

tree_model = *******************
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
y_pred_tree = *******************
print("Accuracy (Decision Tree):", ***********************)
# Out:
# Accuracy (Decision Tree): 0.7966666666666666

# %% [markdown]
# **Train an evaluate with AdaBoostClassifier**

# %%
from sklearn.ensemble import AdaBoostClassifier

boost = **************
boost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3),
#                    random_state=42)

# %%
y_pred_boost = **************
acc_boost = ****************
print("Accuracy (AdaBoost Decision Tree):", ************)
# Out:
# Accuracy (AdaBoost Decision Tree): 0.9266666666666666
